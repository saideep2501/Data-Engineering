# %%
gold_df=spark.sql("""
                  select City, Temperature,Humidity,Country,ingestion_Time
                  from silver_pipe
                  group by City, Temperature,Humidity,Country,ingestion_Time
                  """)

gold_df.write.mode("append").format("delta").saveAsTable("Gold_pipe")
